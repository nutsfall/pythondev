# %% [markdown]
# # 仕様
# * 無限ループを作成します
# * そのなかで「点数を入力してください：」と表示して、テストの点数（整数値）を入力します。なお、入力した点数はあとで使用しますので、変数に格納してください。さらに、入力した点数の件数 人数 をカウンタ変数を用意して数えてください
# * 平均点は「点数の合計値 / 人数」で求めます。点数の合計値 は、繰り返しのたびに入力した点数を合計値用の変数に加算して求めてください
# * -1 と入力されたら、そこで繰り返し処理を終了します
# * 最後に「○○人のテストの平均点は△△点です」と表示してください。平均点は小数第2位を四捨五入し、出力の際に小数第1位までを表示するようにします

# %%
total_score = 0
num_scores = 0

while True:
    score = int(input("点数を入力してください："))

    # 負の数が入力されたらループを終了
    if (score < 0):
        break

    print(f"点数を入力してください： {score}")
    total_score += score
    num_scores += 1

average_score = total_score / num_scores if num_scores > 0 else 0
print(f"{num_scores}人のテストの平均点は{average_score:.2f}点です")
# Out:
# 0人のテストの平均点は0.00点です
