# %% [markdown]
# ## 仕様
# - 「税抜価格を入力してください：」と表示し、キーボードから税抜価格の入力を受け付けます。
# - 税抜価格が入力されたら、税込価格を計算します（小数点以下は四捨五入）。
# - 税額の計算は簡略化のため、税抜価格に一律で10%をかけるものとします。
#
# 計算された税込価格によって処理を分けます。
#
# ### 税込価格が2000円以上の場合
# - 「送料は無料です」と表示します。
#
# ### 税込価格が2000円未満の場合
# - 「送料として350円かかります」と表示します。
# - 送料350円を税込価格に加算します（送料350円は税込価格として扱う）。
#
# 最後に、
# - 「送料込みの価格は○○○円です。」
# の形式で、送料込みの価格を画面に表示します。

# %%
print("商品の価格を入力してください：")
price = int(input())

price_in_tax = price * 1.1

if price_in_tax > 2000:
    shipping = 0
    print(f"送料は無料です")
else:    
    shipping = 350
    print(f"送料として350円かかります")

total = price_in_tax + shipping
print(f"送料込みの価格は {total:.0f} 円です。")
# Out:
# 商品の価格を入力してください：
# 送料として350円かかります
# 送料込みの価格は 2330 円です。
